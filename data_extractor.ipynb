# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display as dsp
from difflib import SequenceMatcher
from scipy.stats import mode #Returns the value of a set that occurs the most
#%matplotlib inline

#latin1, latin9, or win1252.
spend = pd.read_csv('data/WELLCOME_APCspend2013_forThinkful.csv', encoding = 'latin1')
spend.rename(index = str, columns = {"COST (£) charged to Wellcome (inc VAT when charged)" : "Cost"})
dsp(spend.head())

#Starting with publishers. Strip whitespace and make all lowercase.
spend['Publisher'] = spend['Publisher'].str.lower().str.strip()

#This is an attempt to make my life easier
def replace_matches(df, column, accuracy, printme):
    entries = df[column].unique()
    i = 0
    for entry in entries:
        i += 1
        
        for comp in entries:
            if SequenceMatcher(None, entry, comp).ratio() > accuracy and entry != comp: #biomed was replaced with pubmed
                
                if printme == True:
                    print('{} REPLACED WITH {}'.format(entry, comp))
                df[df[column] == entry] = comp
            
def return_acronym(my_string):
    words = my_string.split()
    letters = [word[0] for word in words]
    return "".join(letters)

def expand_acronyms(df, column, accuracy, printme):
    entries = df[column].unique()
    for entry in entries:
        if len(entry) < 10:
            for comp in entries:
                if SequenceMatcher(None, entry, return_acronym(comp)).ratio() > accuracy and entry != comp:
                    if printme == True:
                        print('{} REPLACED WITH {}'.format(entry, comp))
                    df[df[column] == entry] = comp
                
#I will either have to play with these numbers or implement manual double checking.
replace_matches(spend, 'Publisher', 0.81, False)
expand_acronyms(spend, 'Publisher', 0.85, False)
print('Clean-up complete!')

#Stat details:

print('Publisher with most published works:\n', mode(spend['Publisher']))

#Sanity check
#print('\n\n', spend['Publisher'].unique())

#"Elsevier" appears to be the most prolific publisher with 399 published works.
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88
# Clean-up complete!
# Publisher with most published works:
#  ModeResult(mode=array(['elsevier'], dtype=object), count=array([399]))
# C:\Users\peter\Anaconda3\lib\site-packages\scipy\stats\stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
#Deal with arrays :)
costs = spend['COST (£) charged to Wellcome (inc VAT when charged)']

#Extract elements of a string that can be turned into a float
def get_float(str):
    the_float = ''
    point_count = 0
    try:
        for ch in str:
            if ch.isdigit():
                the_float += ch
            if ch == '.' and point_count == 0: #Only include first instance of decimal, I want to change this later
                the_float += ch
                point_count += 1
        return float(the_float)
    except:
        print('This caused problems: ', str)
        
#print('Function test:')
#print(get_float('1.234.50')) #Make this return 1234.50

costs = costs.apply(lambda x: get_float(x))
print(costs)
# Out:
# This caused problems:  cambridge uni press
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  american chemical society
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  acs publications
# This caused problems:  acs publications
# This caused problems:  acs (amercian chemical society) publications
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american physiological society
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american psychiatric association
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society of haematology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  asbmb cadmus
# This caused problems:  asbmb cadmus
# This caused problems:  asbmb/cenveo publisher services
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  american society for microbiology
# This caused problems:  bentham science publishers
# This caused problems:  bentham science publishers
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biomed central
# This caused problems:  biophysical society
# This caused problems:  biophysical society
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  british medical journal
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  bmj publishing group
# This caused problems:  biophysical society
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cadmus journal service
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cadmus journal service
# This caused problems:  asbmb/cenveo publisher services
# This caused problems:  cenveo publisher services
# This caused problems:  cold spring habour press
# This caused problems:  cold spring habour press
# This caused problems:  cold spring habour press
# This caused problems:  cold spring habour press
# This caused problems:  cold spring habour press
# This caused problems:  cold spring habour press
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  cold spring habour press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cambridge uni press
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  cadmus journal services
# This caused problems:  dartmouth journal services
# This caused problems:  dartmouth journal services
# This caused problems:  dartmouth journal services
# This caused problems:  elsevier (cell press)
# This caused problems:  elsevier (cell press)
# This caused problems:  elsevier (cell press)
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  federation of american societies for experimental biology
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  frontiers media
# This caused problems:  future medicine
# This caused problems:  future medicine
# This caused problems:  future medicine
# This caused problems:  future medicine
# This caused problems:  impact journals
# This caused problems:  impact journals
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  international union of crystallography
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons
# This caused problems:  john wiley & sons ltd
# This caused problems:  journal of visualized experiments
# This caused problems:  journal of visualized experiments
# This caused problems:  biomed central
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  landes bioscience
# This caused problems:  mary ann liebert
# This caused problems:  mary ann liebert
# This caused problems:  mary ann liebert
# This caused problems:  mary ann liebert
# This caused problems:  my jove corporation
# This caused problems:  my jove corporation
# This caused problems:  my jove corporation
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  national academy of sciences
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  nature publishing
# This caused problems:  bmj publishing group ltd
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford journals
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford university press
# This caused problems:  oxford university press
# This caused problems:  oxford university press
# This caused problems:  oxford university press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  oxford univ press
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  portland press
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  plos (public library of science)
# This caused problems:  publisher society for endocrinology
# This caused problems:  biomed central
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society for chemistry
# This caused problems:  royal society for chemistry
# This caused problems:  royal society for chemistry
# This caused problems:  royal society for chemistry
# This caused problems:  nature publishing
# This caused problems:  acs publications
# This caused problems:  acs publications
# This caused problems:  sage publications
# This caused problems:  sage publications
# This caused problems:  sage publications
# This caused problems:  nature publishing
# This caused problems:  sheridan press
# This caused problems:  sheridan press
# This caused problems:  sheridan press
# This caused problems:  publisher society for endocrinology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for general microbiology
# This caused problems:  society for leukocyte biology
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  society for general microbiology
# This caused problems:  society for leukocyte biology
# This caused problems:  society for neuroscience
# This caused problems:  society for neuroscience
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  springer - verlag gmbh
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  taylor & francis
# This caused problems:  american physiological society
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  american soc for biochemistry and molecular biology
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  company of biologist
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  endocrine society
# This caused problems:  journal of visualized experiments
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal college of psychiatrists
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  royal society
# This caused problems:  sheridan press
# This caused problems:  sheridan press
# This caused problems:  sheridan press
# This caused problems:  sheridan press
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley subscription services
# This caused problems:  wiley vch
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley blackwell
# This caused problems:  wiley vch
# This caused problems:  wiley vch
# This caused problems:  wiley vch
# This caused problems:  wiley vch
# This caused problems:  wiley vch
# This caused problems:  wiley vch
# This caused problems:  wiley blackwell
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# This caused problems:  wolters kluwer
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15       238.08
# 16       265.67
# 17      2035.00
# 18      3108.08
# 19      1267.76
# 20      2286.73
# 21       947.07
# 22      1186.80
# 23       642.89
# 24      1533.29
# 25      2082.74
# 26      2314.10
# 27       759.67
# 28      1565.26
# 29       572.74
#          ...
# 2097        NaN
# 2098        NaN
# 2099        NaN
# 2100        NaN
# 2101        NaN
# 2102        NaN
# 2103        NaN
# 2104        NaN
# 2105        NaN
# 2106        NaN
# 2107    1900.70
# 2108        NaN
# 2109        NaN
# 2110        NaN
# 2111        NaN
# 2112        NaN
# 2113        NaN
# 2114        NaN
# 2115        NaN
# 2116        NaN
# 2117        NaN
# 2118        NaN
# 2119        NaN
# 2120        NaN
# 2121        NaN
# 2122    1334.15
# 2123    1834.77
# 2124    1834.77
# 2125    2374.52
# 2126        NaN
# Name: COST (£) charged to Wellcome (inc VAT when charged), dtype: float64
