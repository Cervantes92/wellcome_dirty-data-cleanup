# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display as dsp
from difflib import SequenceMatcher
from scipy.stats import mode #Returns the value of a set that occurs the most
#%matplotlib inline

#latin1, latin9, or win1252.
spend = pd.read_csv('data/WELLCOME_APCspend2013_forThinkful.csv', encoding = 'latin1')
dsp(spend.head())

#Starting with publishers. Strip whitespace and make all lowercase.
spend['Publisher'] = spend['Publisher'].str.lower().str.strip()

#This is an attempt to make my life easier
def replace_matches(df, column, accuracy, printme):
    entries = df[column].unique()
    i = 0
    for entry in entries:
        i += 1
        
        for comp in entries:
            if SequenceMatcher(None, entry, comp).ratio() > accuracy and entry != comp: #biomed was replaced with pubmed
                
                if printme == True:
                    print('{} REPLACED WITH {}'.format(entry, comp))
                df[df[column] == entry] = comp
            
def return_acronym(my_string):
    words = my_string.split()
    letters = [word[0] for word in words]
    return "".join(letters)

def expand_acronyms(df, column, accuracy, printme):
    entries = df[column].unique()
    for entry in entries:
        if len(entry) < 10:
            for comp in entries:
                if SequenceMatcher(None, entry, return_acronym(comp)).ratio() > accuracy and entry != comp:
                    if printme == True:
                        print('{} REPLACED WITH {}'.format(entry, comp))
                    df[df[column] == entry] = comp
                
#I will either have to play with these numbers or implement manual double checking.
replace_matches(spend, 'Publisher', 0.81, False)
expand_acronyms(spend, 'Publisher', 0.85, False)
print('Clean-up complete!')

#Stat details:

print('Publisher with most published works:\n', mode(spend['Publisher']))

#San
#print('\n\n', spend['Publisher'].unique())

#"Elsevier" appears to be the most prolific publisher with 399 published works.
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88
# Clean-up complete!
# Publisher with most published works:
#  ModeResult(mode=array(['elsevier'], dtype=object), count=array([399]))
#
#
#  ['cambridge uni press' 'american chemical society'
#  'acs (amercian chemical society) publications' 'acs publications'
#  'aga institute' 'ambsb' 'american association of immunologists'
#  'american college of chest physicians' 'american physiological society'
#  'american psychiatric association' 'american psychiatric publishing'
#  'american public health association'
#  'american soc for biochemistry and molecular biology'
#  'american society for investigative pathology'
#  'american society for microbiology' 'american society for nutrition'
#  'american society of haematology'
#  'american society of human genetics (elsevier)'
#  'american speech-language-hearing association' 'asbmb' 'asbmb cadmus'
#  'asbmb/cenveo publisher services' 'asbmc /cenveo'
#  'association for research in vision & ophthalmology'
#  'bentham science publishers' 'berhahn books' 'biochem journal'
#  'biomed central' 'biophysical society' 'bioscientifica'
#  'blackwell publishing ltd/wiley' 'bmc' 'british medical journal'
#  'bmj group' 'bmj journals' 'bmj publishing group'
#  'bmj publishing group ltd & british thoracic society' 'brill' 'cadmus'
#  'cadmus journal service' 'cambridge journals' 'cell press'
#  'cenveo publisher services' 'coaction' 'cold spring habour press'
#  'cold spring harbor publications' 'company of biologist'
#  'copyright clearace center' 'cadmus journal services'
#  'dartmouth journal services' 'elseveier science' 'elsevier'
#  'elsevier (cell press)' 'elsevier / cell science' 'elsevier b.v.'
#  'elsevier ltd' 'endocrine society' 'european respiratory society'
#  'european society of endocrinolog' 'faseb'
#  'federation of american societies for experimental biology'
#  'ferrata storti foundation' 'frontiers' 'frontiers media'
#  'frontiers research foundation' 'future medicine' 'future science'
#  'hindawi' 'hindawi publishing corporation'
#  'humana press (springer imprint)' 'impact journals' 'informa healthcare'
#  'informa healthcare communications' 'institute of physics'
#  'international aids society'
#  'international union against tuberculosis and lung disease'
#  'international union of crystallography' 'iop publishing' 'ios press'
#  'ivyspring international publisher' 'j med internet research'
#  'john wiley' 'john wiley & sons' 'john wiley & sons ltd'
#  'johns hopkins university press'
#  'journal of the american physiological proceedings of national academy of sciences'
#  'journal of visualized experiments' 'karger' 'landes bioscience' 'lww'
#  'macmillan' 'mary ann liebert' 'mary ann liebert, inc. publishers' 'mdpi'
#  'mit press' 'mit press open access' 'my jove corp' 'my jove corporation'
#  'national academy of sciences'
#  'national academy of sciences of the united states of america' 'nature'
#  'nature pg' 'nature publishing' 'bmj publishing group ltd' 'npg'
#  'open access reg ltd' 'optical society of america' 'oxford univ press'
#  'oxford journals' 'oxford university press' 'palgrave macmillan' 'pion'
#  'plos (public library of science)' 'pnas' 'pnas author publication'
#  'policy press' 'portland press'
#  'proceedings of the national academy of sciences (pnas)'
#  'public.service.co.uk' 'publisher society for endocrinology' 'pubmed'
#  'research media ltd' 'royal college of psychiatrists' 'royal society'
#  'royal society for chemistry' 'sage' 'sage publications'
#  'sage publishers' 'sciedu press' 'scientific research publishing'
#  'sheridan press' 'society for general microbiology'
#  'society for leukocyte biology' 'society for neuroscience'
#  'society for publication of acta dermato-venereologica' 'springer'
#  'springer - verlag gmbh' 'springer science + business media'
#  'springer-verlag gmbh, heidelberger platz 3, d-14197 berlin'
#  'taylor & francis' 'taylor & francis journals'
#  'the american chemical society petroleum research trust'
#  'the american society of pediatrics' 'the boulevard' 'transcript verlag'
#  'university of the basque country press' 'wiley' 'wiley & son'
#  'wiley blackwell' 'wiley online library' 'wiley subscription services'
#  'wiley vch' 'wiley-blackwell, john wiley & sons' 'wolters kluwer'
#  'wolters kluwer health' 'wolters kluwer n.v./lippinott']
# C:\Users\peter\Anaconda3\lib\site-packages\scipy\stats\stats.py:250: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
